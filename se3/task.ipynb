# %%
tiles_leftover =  17 * 6 -  9 * 7 +  5 * 7

# %%
# Out:
# Total tiles needed: 98

# %%
print("Total tiles needed:", total_tiles_needed)
print("Total tiles bought:", total_tiles_bought)
# Out:
# Total tiles needed: 98
# Total tiles bought: 102

# %%
print("Tiles leftover:", tiles_leftover)
# Out:
# Tiles leftover: 4
