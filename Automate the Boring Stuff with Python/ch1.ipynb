# %%
2
# Out:
# 2

# %%
"hi"
# Out:
# 'hi'

# %%
hi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 hi
#
# NameError: name 'hi' is not defined

# %%
3**2*2
# Out:
# 18

# %% [markdown]
# ** % // / * - +

# %%
9**99
# Out:
# 29512665430652752148753480226197736314359272517043832886063884637676943433478020332709411004889

# %%
         2+              9
# Out:
# 11

# %%
print(21 % 7)
print(9 % 8)
print(88 % 80)
# Out:
# 0
# 1
# 8

# %%
print(21 % 7)
print(9 % 8)
print(88 % 80)
5
# Out:
# 0
# 1
# 8
# 5

# %%
8
"hi"
"hillo"
# Out:
# 'hillo'

# %%
5+
# Out:
#   Cell In[48], line 1
#     5+
#       ^
# SyntaxError: invalid syntax

# %%
6 +
# Out:
#   Cell In[53], line 1
#     6 +
#        ^
# SyntaxError: invalid syntax

# %%
9+*9
# Out:
#   Cell In[54], line 1
#     9+*9
#       ^
# SyntaxError: invalid syntax

# %%
'stris'
# Out:
# 'stris'

# %%
"hi"+"world"
# Out:
# 'hiworld'

# %% [markdown]
# string concatenation str+str
# -----
# str + int -> Error

# %%
's' + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 's' + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
"s" + str(5)
# Out:
# 's5'

# %%
'hossam '*99999
# Out:
# 'hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam hossam ho ...

# %% [markdown]
# The * operator is used for multiplication when it operates on two inte
# ger or floating-point values. But when the * operator is used on one string
# value and one integer value, it becomes the string replication operator. Enter
# a string multiplied by a number into the interactive shell to see this in action.

# %%
"a"*"a"
"k"*.5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 "a"*"a"
#       2 "k"*.5
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
# This is
# called overwriting the variable.

# %%
a=5
a=a+5
a
# Out:
# 10

# %% [markdown]
# 1. It can be only one word.
# 2. It can use only letters, numbers, and the underscore (_) character.
# 3. It can’t begin with a number.

# %%
print("Hello " + input("What is your name? ") + "!")
# Out:
# Hello !

# %%
print(len("een the two:The file editlikujyfhghj56744,jhjghjkor window will not have the "))
# Out:
# 77

# %%
print(5+5)
# Out:
# 10

# %%
myname = input('What is your name? ')

print('It is good to meet you, ' + myname)
# Out:
# It is good to meet you, kk

# %%
l= len(555)
l
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 l= len(555)
#       2 len()
#       3 l
#
# TypeError: object of type 'int' has no len()

# %%
len()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 len()
#
# TypeError: len() takes exactly one argument (0 given)

# %%
print('I am ' + 29 + ' years old.')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 print('I am ' + 29 + ' years old.')
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # input() function always returns a string, even if the user enters a number

# %%
a=int('9.3')
a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 a=int('9.3')
#       2 a
#
# ValueError: invalid literal for int() with base 10: '9.3'

# %%
42==42.00
# Out:
# True
